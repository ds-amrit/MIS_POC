# %% [markdown]
# In this notebook MIS data for 2018 is merged from different excel files and processed to create consolidated FINANCIALS dataframe for further visulaization

# %%
# Import Libraries
import glob
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Later define as config variable for financial data
financials = ['# Cash&Carry Retail Stores','Revenues ($K)','COGS  ($K)','Gross Margins  ($K)','Logistics  ($K)',
                    'Net Margins  ($K)','Net Indirect Expenses  ($K)','    Salaries  ($K)','    Overheads  ($K)','EBITDA  ($K)',
                    'Change in working capital  ($K)','Finance Costs  ($K)','Net Flow (Burn)  ($K)','index']

# %%
def clean_data(df):
    '''
        This function drops unwanted columns, null value rows and 
        transposes the df for further processing.
    '''
    
    df.drop(labels=['KPI TYPE','REMARKS / COMMENTS'],axis=1,inplace=True)
    df.dropna(how='all',inplace=True)
    dfT = df.T
    dfT.columns = dfT.iloc[0]
    dfT = dfT.iloc[1:]
    dfT.reset_index(inplace=True)
    #dfT['month'] = [i.split(' ')[0] for i in dfT['index']]
    #dfT.drop(columns='index',inplace=True)
    dfT.reset_index(drop=True,inplace=True)
    return dfT

# %%
# Read all excel files in the given directory path
path = "data\MIS 2018"

filename = glob.glob(path + "\*.xlsx")
[i for i in filename]
# Out:
# ['data\\MIS 2018\\MIS - August 2018.xlsx',
#  'data\\MIS 2018\\MIS - December 2018.xlsx',
#  'data\\MIS 2018\\MIS - October 2018.xlsx',
#  'data\\MIS 2018\\MIS - September 2018.xlsx']

# %%
# Initialize empty df with column names to consolidate data from all excel files
dflong = pd.DataFrame(columns=financials)

# Loop to read all excel files and filter financial data
for file in filename[:4]:
   print("Reading file = ",file)
   df = pd.read_excel(file)
   # Remove unwanted columns and transpose data
   dfT = clean_data(df)
   # Filter Finance Data
   dfT = dfT.loc[:,financials]
   dflong = pd.concat([dflong,dfT],ignore_index=True,axis=0)
# Out:
# Reading file =  data\MIS 2018\MIS - August 2018.xlsx
# Index(['# Cash&Carry Retail Stores', 'Revenues ($K)', 'COGS  ($K)',
#        'Gross Margins  ($K)', 'Logistics  ($K)', 'Net Margins  ($K)',
#        'Net Indirect Expenses  ($K)', '    Salaries  ($K)',
#        '    Overheads  ($K)', 'EBITDA  ($K)',
#        'Change in working capital  ($K)', 'Finance Costs  ($K)',
#        'Net Flow (Burn)  ($K)', 'index'],
#       dtype='object', name='PARAMETER')
# Reading file =  data\MIS 2018\MIS - December 2018.xlsx
# Index(['# Cash&Carry Retail Stores', 'Revenues ($K)', 'COGS  ($K)',
#        'Gross Margins  ($K)', 'Logistics  ($K)', 'Net Margins  ($K)',
#        'Net Indirect Expenses  ($K)', '    Salaries  ($K)',
#        '    Overheads  ($K)', 'EBITDA  ($K)',
#        'Change in working capital  ($K)', 'Finance Costs  ($K)',
#        'Net Flow (Burn)  ($K)', 'index'],
#       dtype='object', name='PARAMETER')
# Reading file =  data\MIS 2018\MIS - October 2018.xlsx
# Index(['# Cash&Carry Retail Stores', 'Revenues ($K)', 'COGS  ($K)',
#        'Gross Margins  ($K)', 'Logistics  ($K)', 'Net Margins  ($K)',
#        'Net Indirect Expenses  ($K)', '    Salaries  ($K)',
#        '    Overheads  ($K)', 'EBITDA  ($K)',
#        'Change in working capital  ($K)', 'Finance Costs  ($K)',
#        'Net Flow (Burn)  ($K)', 'index'],
#       dtype='object', name='PARAMETER')
# Reading file =  data\MIS 2018\MIS - September 2018.xlsx
# Index(['# Cash&Carry Retail Stores', 'Revenues ($K)', 'COGS  ($K)',
#        'Gross Margins  ($K)', 'Logistics  ($K)', 'Net Margins  ($K)',
#        'Net Indirect Expenses  ($K)', '    Salaries  ($K)',
#        '    Overheads  ($K)', 'EBITDA  ($K)',
#        'Change in working capital  ($K)', 'Finance Costs  ($K)',
#        'Net Flow (Burn)  ($K)', 'index'],
#       dtype='object', name='PARAMETER')

# %%
display(dflong)
# Out:
#    # Cash&Carry Retail Stores Revenues ($K) COGS  ($K) Gross Margins  ($K)
# 0                          53     10.993646  -5.683662            5.309985  \
# 1                          61     11.084431  -5.512785            5.571646
# 2                          81     14.486538  -6.432023            8.054515
# 3                         108     20.792985 -12.030154            8.762831
# 4                         127     30.336169 -21.256138            9.080031
# 5                         150     33.882353 -23.867511           10.014842
# 6                          72       14.8718  -7.323431            7.548369
# 7                          88     19.900877 -11.068354            8.832523
# 8                         105     24.036923     -13.02           11.016923
# 9                          61     11.084431  -5.512785            5.571646
# 10                         72       14.8718  -7.323431            7.548369
# 11                        100     19.673077  -9.836538            9.836538
#
#    Logistics  ($K) Net Margins  ($K) Net Indirect Expenses  ($K)
# 0        -3.190538          2.119446                  -43.025662  \
# 1        -3.210523          2.361123                  -49.070123
# 2        -3.852628          4.201888                  -52.608585
# 3          -6.2748          2.488031                  -54.949415
# 4       -10.603338         -1.523308                     -66.174
# 5       -11.080908         -1.066066                  -62.327846
# 6        -3.031538          4.516831                  -63.719046
# 7        -5.248508          3.584015                  -58.779492
# 8        -5.773358          5.243565                    -64.4718
# 9        -3.210523          2.361123                  -49.070123
# 10       -3.031538          4.516831                  -63.719046
# 11       -3.637846          6.198692                  -55.257508
#
#        Salaries  ($K)     Overheads  ($K) EBITDA  ($K)
# 0          -21.544554          -21.481108   -40.906215  \
# 1          -25.009231          -24.060892      -46.709
# 2          -28.547692          -24.060892   -48.406697
# 3          -30.156385          -24.793031   -52.461385
# 4          -35.519631          -30.654369   -67.697308
# 5          -35.519631          -26.808215   -63.393912
# 6          -30.887662          -32.831385   -59.202215
# 7          -30.365769          -28.413723   -55.195477
# 8          -32.211923          -32.259877   -59.228235
# 9          -25.009231          -24.060892      -46.709
# 10         -30.887662          -32.831385   -59.202215
# 11         -29.656892          -25.600615   -49.058815
#
#    Change in working capital  ($K) Finance Costs  ($K) Net Flow (Burn)  ($K)
# 0                        -0.336508           -2.321031            -43.563754  \
# 1                        -1.584662           -2.321031            -50.614692
# 2                         0.898077           -2.321031            -49.829651
# 3                        -4.373462           -2.321031            -59.155877
# 4                        -9.957831           -2.321031            -79.976169
# 5                        -3.546184           -2.321031            -69.261127
# 6                          -3.4084           -2.321031            -64.931646
# 7                           0.1416           -2.321031            -57.374908
# 8                        -1.729231           -2.321031            -63.278497
# 9                        -1.584662           -2.321031            -50.614692
# 10                         -3.4084           -2.321031            -64.931646
# 11                       -1.211538           -2.321031            -52.591385
#
#                            index
# 0          JULY (BASELINE MONTH)
# 1             AUGUST (MIS MONTH)
# 2       SEPTEMBER (TARGET MONTH)
# 3     NOVEMBER\n(BASELINE MONTH)
# 4          DECEMBER\n(MIS MONTH)
# 5        JANUARY\n(TARGET MONTH)
# 6   SEPTEMBER\n (BASELINE MONTH)
# 7           OCTOBER\n(MIS MONTH)
# 8      NOVEMBER \n(TARGET MONTH)
# 9     AUGUST \n (BASELINE MONTH)
# 10       SEPTEMBER \n(MIS MONTH)
# 11      OCTOBER \n(TARGET MONTH)

# %%
# Dropping the rows with Target Month in index column
newdf = dflong[ dflong['index'].str.contains('TARGET MONTH')==False ]
newdf
# Out:
#    # Cash&Carry Retail Stores Revenues ($K) COGS  ($K) Gross Margins  ($K)
# 0                          53     10.993646  -5.683662            5.309985  \
# 1                          61     11.084431  -5.512785            5.571646
# 3                         108     20.792985 -12.030154            8.762831
# 4                         127     30.336169 -21.256138            9.080031
# 6                          72       14.8718  -7.323431            7.548369
# 7                          88     19.900877 -11.068354            8.832523
# 9                          61     11.084431  -5.512785            5.571646
# 10                         72       14.8718  -7.323431            7.548369
#
#    Logistics  ($K) Net Margins  ($K) Net Indirect Expenses  ($K)
# 0        -3.190538          2.119446                  -43.025662  \
# 1        -3.210523          2.361123                  -49.070123
# 3          -6.2748          2.488031                  -54.949415
# 4       -10.603338         -1.523308                     -66.174
# 6        -3.031538          4.516831                  -63.719046
# 7        -5.248508          3.584015                  -58.779492
# 9        -3.210523          2.361123                  -49.070123
# 10       -3.031538          4.516831                  -63.719046
#
#        Salaries  ($K)     Overheads  ($K) EBITDA  ($K)
# 0          -21.544554          -21.481108   -40.906215  \
# 1          -25.009231          -24.060892      -46.709
# 3          -30.156385          -24.793031   -52.461385
# 4          -35.519631          -30.654369   -67.697308
# 6          -30.887662          -32.831385   -59.202215
# 7          -30.365769          -28.413723   -55.195477
# 9          -25.009231          -24.060892      -46.709
# 10         -30.887662          -32.831385   -59.202215
#
#    Change in working capital  ($K) Finance Costs  ($K) Net Flow (Burn)  ($K)
# 0                        -0.336508           -2.321031            -43.563754  \
# 1                        -1.584662           -2.321031            -50.614692
# 3                        -4.373462           -2.321031            -59.155877
# 4                        -9.957831           -2.321031            -79.976169
# 6                          -3.4084           -2.321031            -64.931646
# 7                           0.1416           -2.321031            -57.374908
# 9                        -1.584662           -2.321031            -50.614692
# 10                         -3.4084           -2.321031            -64.931646
#
#                            index
# 0          JULY (BASELINE MONTH)
# 1             AUGUST (MIS MONTH)
# 3     NOVEMBER\n(BASELINE MONTH)
# 4          DECEMBER\n(MIS MONTH)
# 6   SEPTEMBER\n (BASELINE MONTH)
# 7           OCTOBER\n(MIS MONTH)
# 9     AUGUST \n (BASELINE MONTH)
# 10       SEPTEMBER \n(MIS MONTH)

# %%
# Correcting the format of months
newdf['month'] = [i.split(' ')[0] for i in newdf['index']]
newdf
# Out:
# C:\Users\amrit\AppData\Local\Temp\ipykernel_5240\2522360063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['month'] = [i.split(' ')[0] for i in newdf['index']]
#    # Cash&Carry Retail Stores Revenues ($K) COGS  ($K) Gross Margins  ($K)
# 0                          53     10.993646  -5.683662            5.309985  \
# 1                          61     11.084431  -5.512785            5.571646
# 3                         108     20.792985 -12.030154            8.762831
# 4                         127     30.336169 -21.256138            9.080031
# 6                          72       14.8718  -7.323431            7.548369
# 7                          88     19.900877 -11.068354            8.832523
# 9                          61     11.084431  -5.512785            5.571646
# 10                         72       14.8718  -7.323431            7.548369
#
#    Logistics  ($K) Net Margins  ($K) Net Indirect Expenses  ($K)
# 0        -3.190538          2.119446                  -43.025662  \
# 1        -3.210523          2.361123                  -49.070123
# 3          -6.2748          2.488031                  -54.949415
# 4       -10.603338         -1.523308                     -66.174
# 6        -3.031538          4.516831                  -63.719046
# 7        -5.248508          3.584015                  -58.779492
# 9        -3.210523          2.361123                  -49.070123
# 10       -3.031538          4.516831                  -63.719046
#
#        Salaries  ($K)     Overheads  ($K) EBITDA  ($K)
# 0          -21.544554          -21.481108   -40.906215  \
# 1          -25.009231          -24.060892      -46.709
# 3          -30.156385          -24.793031   -52.461385
# 4          -35.519631          -30.654369   -67.697308
# 6          -30.887662          -32.831385   -59.202215
# 7          -30.365769          -28.413723   -55.195477
# 9          -25.009231          -24.060892      -46.709
# 10         -30.887662          -32.831385   -59.202215
#
#    Change in working capital  ($K) Finance Costs  ($K) Net Flow (Burn)  ($K)
# 0                        -0.336508           -2.321031            -43.563754  \
# 1                        -1.584662           -2.321031            -50.614692
# 3                        -4.373462           -2.321031            -59.155877
# 4                        -9.957831           -2.321031            -79.976169
# 6                          -3.4084           -2.321031            -64.931646
# 7                           0.1416           -2.321031            -57.374908
# 9                        -1.584662           -2.321031            -50.614692
# 10                         -3.4084           -2.321031            -64.931646
#
#                            index                month
# 0          JULY (BASELINE MONTH)                 JULY
# 1             AUGUST (MIS MONTH)               AUGUST
# 3     NOVEMBER\n(BASELINE MONTH)  NOVEMBER\n(BASELINE
# 4          DECEMBER\n(MIS MONTH)       DECEMBER\n(MIS
# 6   SEPTEMBER\n (BASELINE MONTH)          SEPTEMBER\n
# 7           OCTOBER\n(MIS MONTH)        OCTOBER\n(MIS
# 9     AUGUST \n (BASELINE MONTH)               AUGUST
# 10       SEPTEMBER \n(MIS MONTH)            SEPTEMBER

# %%
# Correcting the format of months
newdf['month'] = [i.split('\n')[0] for i in newdf['month']]
newdf
# Out:
# C:\Users\amrit\AppData\Local\Temp\ipykernel_5240\1860540755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['month'] = [i.split('\n')[0] for i in newdf['month']]
#    # Cash&Carry Retail Stores Revenues ($K) COGS  ($K) Gross Margins  ($K)
# 0                          53     10.993646  -5.683662            5.309985  \
# 1                          61     11.084431  -5.512785            5.571646
# 3                         108     20.792985 -12.030154            8.762831
# 4                         127     30.336169 -21.256138            9.080031
# 6                          72       14.8718  -7.323431            7.548369
# 7                          88     19.900877 -11.068354            8.832523
# 9                          61     11.084431  -5.512785            5.571646
# 10                         72       14.8718  -7.323431            7.548369
#
#    Logistics  ($K) Net Margins  ($K) Net Indirect Expenses  ($K)
# 0        -3.190538          2.119446                  -43.025662  \
# 1        -3.210523          2.361123                  -49.070123
# 3          -6.2748          2.488031                  -54.949415
# 4       -10.603338         -1.523308                     -66.174
# 6        -3.031538          4.516831                  -63.719046
# 7        -5.248508          3.584015                  -58.779492
# 9        -3.210523          2.361123                  -49.070123
# 10       -3.031538          4.516831                  -63.719046
#
#        Salaries  ($K)     Overheads  ($K) EBITDA  ($K)
# 0          -21.544554          -21.481108   -40.906215  \
# 1          -25.009231          -24.060892      -46.709
# 3          -30.156385          -24.793031   -52.461385
# 4          -35.519631          -30.654369   -67.697308
# 6          -30.887662          -32.831385   -59.202215
# 7          -30.365769          -28.413723   -55.195477
# 9          -25.009231          -24.060892      -46.709
# 10         -30.887662          -32.831385   -59.202215
#
#    Change in working capital  ($K) Finance Costs  ($K) Net Flow (Burn)  ($K)
# 0                        -0.336508           -2.321031            -43.563754  \
# 1                        -1.584662           -2.321031            -50.614692
# 3                        -4.373462           -2.321031            -59.155877
# 4                        -9.957831           -2.321031            -79.976169
# 6                          -3.4084           -2.321031            -64.931646
# 7                           0.1416           -2.321031            -57.374908
# 9                        -1.584662           -2.321031            -50.614692
# 10                         -3.4084           -2.321031            -64.931646
#
#                            index      month
# 0          JULY (BASELINE MONTH)       JULY
# 1             AUGUST (MIS MONTH)     AUGUST
# 3     NOVEMBER\n(BASELINE MONTH)   NOVEMBER
# 4          DECEMBER\n(MIS MONTH)   DECEMBER
# 6   SEPTEMBER\n (BASELINE MONTH)  SEPTEMBER
# 7           OCTOBER\n(MIS MONTH)    OCTOBER
# 9     AUGUST \n (BASELINE MONTH)     AUGUST
# 10       SEPTEMBER \n(MIS MONTH)  SEPTEMBER

# %%
# Check for duplicates and drop them
newdf.drop_duplicates(subset=newdf.columns[:(len(newdf.columns)-2)],inplace=True)
newdf
# Out:
# C:\Users\amrit\AppData\Local\Temp\ipykernel_5240\82728929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf.drop_duplicates(subset=newdf.columns[:(len(newdf.columns)-2)],inplace=True)
#   # Cash&Carry Retail Stores Revenues ($K) COGS  ($K) Gross Margins  ($K)
# 0                         53     10.993646  -5.683662            5.309985  \
# 1                         61     11.084431  -5.512785            5.571646
# 3                        108     20.792985 -12.030154            8.762831
# 4                        127     30.336169 -21.256138            9.080031
# 6                         72       14.8718  -7.323431            7.548369
# 7                         88     19.900877 -11.068354            8.832523
#
#   Logistics  ($K) Net Margins  ($K) Net Indirect Expenses  ($K)
# 0       -3.190538          2.119446                  -43.025662  \
# 1       -3.210523          2.361123                  -49.070123
# 3         -6.2748          2.488031                  -54.949415
# 4      -10.603338         -1.523308                     -66.174
# 6       -3.031538          4.516831                  -63.719046
# 7       -5.248508          3.584015                  -58.779492
#
#       Salaries  ($K)     Overheads  ($K) EBITDA  ($K)
# 0         -21.544554          -21.481108   -40.906215  \
# 1         -25.009231          -24.060892      -46.709
# 3         -30.156385          -24.793031   -52.461385
# 4         -35.519631          -30.654369   -67.697308
# 6         -30.887662          -32.831385   -59.202215
# 7         -30.365769          -28.413723   -55.195477
#
#   Change in working capital  ($K) Finance Costs  ($K) Net Flow (Burn)  ($K)
# 0                       -0.336508           -2.321031            -43.563754  \
# 1                       -1.584662           -2.321031            -50.614692
# 3                       -4.373462           -2.321031            -59.155877
# 4                       -9.957831           -2.321031            -79.976169
# 6                         -3.4084           -2.321031            -64.931646
# 7                          0.1416           -2.321031            -57.374908
#
#                           index      month
# 0         JULY (BASELINE MONTH)       JULY
# 1            AUGUST (MIS MONTH)     AUGUST
# 3    NOVEMBER\n(BASELINE MONTH)   NOVEMBER
# 4         DECEMBER\n(MIS MONTH)   DECEMBER
# 6  SEPTEMBER\n (BASELINE MONTH)  SEPTEMBER
# 7          OCTOBER\n(MIS MONTH)    OCTOBER

# %%
# Convert month name to number
from datetime import datetime

newdf['month_number'] = [datetime.strptime(i, '%B').month for i in newdf.month]
# Out:
# C:\Users\amrit\AppData\Local\Temp\ipykernel_5240\2665377525.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['month_number'] = [datetime.strptime(i, '%B').month for i in newdf.month]

# %%
# Sort the df based on month number
newdf = newdf.sort_values(by=['month_number']).set_index('month_number',drop=True)
newdf
# Out:
#              # Cash&Carry Retail Stores Revenues ($K) COGS  ($K)
# month_number
# 7                                    53     10.993646  -5.683662  \
# 8                                    61     11.084431  -5.512785
# 9                                    72       14.8718  -7.323431
# 10                                   88     19.900877 -11.068354
# 11                                  108     20.792985 -12.030154
# 12                                  127     30.336169 -21.256138
#
#              Gross Margins  ($K) Logistics  ($K) Net Margins  ($K)
# month_number
# 7                       5.309985       -3.190538          2.119446  \
# 8                       5.571646       -3.210523          2.361123
# 9                       7.548369       -3.031538          4.516831
# 10                      8.832523       -5.248508          3.584015
# 11                      8.762831         -6.2748          2.488031
# 12                      9.080031      -10.603338         -1.523308
#
#              Net Indirect Expenses  ($K)     Salaries  ($K)
# month_number
# 7                             -43.025662         -21.544554  \
# 8                             -49.070123         -25.009231
# 9                             -63.719046         -30.887662
# 10                            -58.779492         -30.365769
# 11                            -54.949415         -30.156385
# 12                               -66.174         -35.519631
#
#                  Overheads  ($K) EBITDA  ($K) Change in working capital  ($K)
# month_number
# 7                     -21.481108   -40.906215                       -0.336508  \
# 8                     -24.060892      -46.709                       -1.584662
# 9                     -32.831385   -59.202215                         -3.4084
# 10                    -28.413723   -55.195477                          0.1416
# 11                    -24.793031   -52.461385                       -4.373462
# 12                    -30.654369   -67.697308                       -9.957831
#
#              Finance Costs  ($K) Net Flow (Burn)  ($K)
# month_number
# 7                      -2.321031            -43.563754  \
# 8                      -2.321031            -50.614692
# 9                      -2.321031            -64.931646
# 10                     -2.321031            -57.374908
# 11                     -2.321031            -59.155877
# 12                     -2.321031            -79.976169
#
#                                      index      month
# month_number
# 7                    JULY (BASELINE MONTH)       JULY
# 8                       AUGUST (MIS MONTH)     AUGUST
# 9             SEPTEMBER\n (BASELINE MONTH)  SEPTEMBER
# 10                    OCTOBER\n(MIS MONTH)    OCTOBER
# 11              NOVEMBER\n(BASELINE MONTH)   NOVEMBER
# 12                   DECEMBER\n(MIS MONTH)   DECEMBER

# %%
# Drop index column to create final finance dataframe
finance_df = newdf.drop(columns='index')
finance_df
# Out:
#              # Cash&Carry Retail Stores Revenues ($K) COGS  ($K)
# month_number
# 7                                    53     10.993646  -5.683662  \
# 8                                    61     11.084431  -5.512785
# 9                                    72       14.8718  -7.323431
# 10                                   88     19.900877 -11.068354
# 11                                  108     20.792985 -12.030154
# 12                                  127     30.336169 -21.256138
#
#              Gross Margins  ($K) Logistics  ($K) Net Margins  ($K)
# month_number
# 7                       5.309985       -3.190538          2.119446  \
# 8                       5.571646       -3.210523          2.361123
# 9                       7.548369       -3.031538          4.516831
# 10                      8.832523       -5.248508          3.584015
# 11                      8.762831         -6.2748          2.488031
# 12                      9.080031      -10.603338         -1.523308
#
#              Net Indirect Expenses  ($K)     Salaries  ($K)
# month_number
# 7                             -43.025662         -21.544554  \
# 8                             -49.070123         -25.009231
# 9                             -63.719046         -30.887662
# 10                            -58.779492         -30.365769
# 11                            -54.949415         -30.156385
# 12                               -66.174         -35.519631
#
#                  Overheads  ($K) EBITDA  ($K) Change in working capital  ($K)
# month_number
# 7                     -21.481108   -40.906215                       -0.336508  \
# 8                     -24.060892      -46.709                       -1.584662
# 9                     -32.831385   -59.202215                         -3.4084
# 10                    -28.413723   -55.195477                          0.1416
# 11                    -24.793031   -52.461385                       -4.373462
# 12                    -30.654369   -67.697308                       -9.957831
#
#              Finance Costs  ($K) Net Flow (Burn)  ($K)      month
# month_number
# 7                      -2.321031            -43.563754       JULY
# 8                      -2.321031            -50.614692     AUGUST
# 9                      -2.321031            -64.931646  SEPTEMBER
# 10                     -2.321031            -57.374908    OCTOBER
# 11                     -2.321031            -59.155877   NOVEMBER
# 12                     -2.321031            -79.976169   DECEMBER

# %%
# Save the dataset locally
finance_df.to_csv('data/MIS 2018/finance_df.csv')
